# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/comps/9/2024-2025/2024-2025-Premier-League-Stats',
                  attrs={"id":"results2024-202591_overall"})[0]

# %%
df.head()
# Out:
#    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1        Liverpool  38  25   9   4  86  41  45   84    2.21  82.2  38.6
# 1   2          Arsenal  38  20  14   4  69  34  35   74    1.95  59.9  34.4
# 2   3  Manchester City  38  21   8   9  72  44  28   71    1.87  68.1  47.7
# 3   4          Chelsea  38  20   9   9  64  43  21   69    1.82  67.8  47.3
# 4   5    Newcastle Utd  38  20   6  12  68  47  21   66    1.74  63.8  45.5
#
#     xGD  xGD/90  Attendance      Top Team Scorer      Goalkeeper  \
# 0  43.6    1.15       60324   Mohamed Salah - 29         Alisson
# 1  25.5    0.67       60251      Kai Havertz - 9      David Raya
# 2  20.4    0.54       52756  Erling Haaland - 22         Ederson
# 3  20.5    0.54       39672     Cole Palmer - 15  Robert Sánchez
# 4  18.3    0.48       52187  Alexander Isak - 23       Nick Pope
#
#                                   Notes
# 0  → Champions League via league finish
# ...

# %%
df_chelsea = pd.read_html('https://fbref.com/en/squads/cff3d9bb/2024-2025/Chelsea-Stats',
                          attrs={"id":"stats_standard_9"})[0]

# %%
df_chelsea.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Moisés Caicedo             ec ECU              MF,DF               22.0
# 1        Cole Palmer            eng ENG              MF,FW               22.0
# 2       Levi Colwill            eng ENG                 DF               21.0
# 3     Marc Cucurella             es ESP                 DF               26.0
# 4     Enzo Fernández             ar ARG                 MF               23.0
#
#   Unnamed: 4_level_0 Playing Time               Performance       ...  \
#                   MP       Starts     Min   90s         Gls  Ast  ...
# 0                 38           38  3351.0  37.2         1.0  2.0  ...
# 1                 37           36  3191.0  35.5        15.0  8.0  ...
# 2                 35           35  3149.0  35.0         2.0  1.0  ...
# 3                 36           33  2988.0  33.2         5.0  1.0  ...
# ...

# %%
df_chelsea.columns.values
# Out:
# array([('Unnamed: 0_level_0', 'Player'), ('Unnamed: 1_level_0', 'Nation'),
#        ('Unnamed: 2_level_0', 'Pos'), ('Unnamed: 3_level_0', 'Age'),
#        ('Unnamed: 4_level_0', 'MP'), ('Playing Time', 'Starts'),
#        ('Playing Time', 'Min'), ('Playing Time', '90s'),
#        ('Performance', 'Gls'), ('Performance', 'Ast'),
#        ('Performance', 'G+A'), ('Performance', 'G-PK'),
#        ('Performance', 'PK'), ('Performance', 'PKatt'),
#        ('Performance', 'CrdY'), ('Performance', 'CrdR'),
#        ('Expected', 'xG'), ('Expected', 'npxG'), ('Expected', 'xAG'),
#        ('Expected', 'npxG+xAG'), ('Progression', 'PrgC'),
#        ('Progression', 'PrgP'), ('Progression', 'PrgR'),
#        ('Per 90 Minutes', 'Gls'), ('Per 90 Minutes', 'Ast'),
#        ('Per 90 Minutes', 'G+A'), ('Per 90 Minutes', 'G-PK'),
#        ('Per 90 Minutes', 'G+A-PK'), ('Per 90 Minutes', 'xG'),
#        ('Per 90 Minutes', 'xAG'), ('Per 90 Minutes', 'xG+xAG'),
# ...

# %%
# Getting rid of multiindex columns by joining tuple elements by using underscore 
df_chelsea.columns = ['_'.join(col).strip() for col in df_chelsea.columns.values]

# %%
df_chelsea.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0            Moisés Caicedo                    ec ECU                  MF,DF
# 1               Cole Palmer                   eng ENG                  MF,FW
# 2              Levi Colwill                   eng ENG                     DF
# 3            Marc Cucurella                    es ESP                     DF
# 4            Enzo Fernández                    ar ARG                     MF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_MP  Playing Time_Starts  \
# 0                    22.0                     38                   38
# 1                    22.0                     37                   36
# 2                    21.0                     35                   35
# 3                    26.0                     36                   33
# 4                    23.0                     36                   32
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  ...  \
# ...
